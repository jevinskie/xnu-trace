# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
# %matplotlib inline

# %%
rect = patches.Rectangle((4, 4), 1, 1, fill=True, edgecolor="black", facecolor="red")

# %%
plt.xlim([0, 32])
plt.ylim([0, 8])
plt.gca().add_patch(rect)
